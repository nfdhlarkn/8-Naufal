# %% [markdown]
# # PRACTICE TIME!! &#128074;
#
# ![meme](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExYm04Yjltbm1yenF6MTQwc2twNGxmeXVtODl4eGVidGx5ODZ3bzcxYyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/XIqCQx02E1U9W/giphy.gif)
#
# ### And one more thing...
#
# try to not open any GEN AI okay? this will helped you more to understand ^_^

# %% [markdown]
# # Easy level
# ### Test case 1 : write a function to convert Celsius to Fahrenheit
#
# ***You can only write 1 line in a function***
#
# Formula: `F = (C * 9/5) + 32`

# %%
# write and continue the code down here
def farenheit(c):
    return c * 9 / 5 + 32

# Test
print(farenheit(0))    # Expected: 32.0
print(farenheit(100))  # Expected: 212.0
# Out:
# 32.0
# 212.0

# %% [markdown]
# # Medium level
#
# ### Test case 2 : write a function to count vowels in a string
#
# Count vowels: a, i, u, e, o (case-insensitive).

# %%
def vowels(text):
    count = 0
    for char in text:
        if char.lower() in 'aeiou':
            count += 1
    return count

# Test
print(vowels("Hello World"))  # Expected: 3  (e,o,o)
print(vowels("PYTHON"))       # Expected: 1  (o)
# Out:
# 3
# 1

# %% [markdown]
# # Medium level
# ### Test case 3 : write a function to summarize shopping cart
#
# Given a list of prices, return (total, average, max). Use built-in functions when possible.

# %%
def counter(prices):
    total = sum(prices)
    average = total / len(prices)
    max_price = max(prices)
    return total, average, max_price

# Test
print(counter([10, 20, 30]))         # Expected: (60, 20.0, 30)
print(counter([5]))                  # Expected: (5, 5.0, 5)
# Out:
# (60, 20.0, 30)
# (5, 5.0, 5)

# %% [markdown]
# # Hard level
# ### Test case 4 : write a function to remove duplicates while keeping order
#
# Example: `[1,2,1,3,2] -> [1,2,3]`

# %%
def remover(items):
  temp = set(items)
  return list(temp)

# Test
print(remover([1, 2, 1, 3, 2]))                 # Expected: [1, 2, 3]
print(remover(["a", "b", "a", "c", "b"]))       # Expected: ['a', 'b', 'c']
# Out:
# [1, 2, 3]
# ['a', 'c', 'b']

# %% [markdown]
# # Expert level
# ### Test case 5 : create a class StudentGradeBook
#
# Requirements:
# - `__init__(self, name)` sets name and empty list of scores
# - `add_score(self, score)` adds score (0-100). If invalid, return "Invalid score"
# - `average(self)` returns average score (float). If no scores, return 0
# - `status(self)` returns:
#   - "Pass" if average >= 75
#   - "Remedial" if 60 <= average < 75
#   - "Fail" if average < 60

# %%
class StudentGradeBook:
    def __init__(self, name):
        self.list_score = []

    def add_score(self, score):
        if 0 <= score <= 100:
            self.list_score.append(score)
            return f"Added {score}"
        else:
            return "Invalid score"

    def average(self):
        if len(self.list_score) == 0:
            return 0
        else:
            return sum(self.list_score) / len(self.list_score)

    def status(self):
        if self.average() >= 75:
            return "Pass"
        elif 60 <= self.average() < 75:
            return "Remedial"
        else:
            return "Fail"

# Test
s = StudentGradeBook("Alya")
print(s.average())              # Expected: 0
print(s.status())               # Expected: Fail
print(s.add_score(80))          # Expected: Added 80
print(s.add_score(70))          # Expected: Added 70
print(s.add_score(120))         # Expected: Invalid score
print(s.average())              # Expected: 75.0
print(s.status())               # Expected: Pass
# Out:
# 0
# Fail
# Added 80
# Added 70
# Invalid score
# 75.0
# Pass
