# %% [markdown]
# <a href="https://colab.research.google.com/github/nfdhlarkn/8-Naufal/blob/main/World_Naufal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Naufal's Notebook**
# Just for testing
